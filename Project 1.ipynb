# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('Number_of_filled_jobs_by_age_region.csv')

# %%
df2 = pd.read_csv('Number_of_filled_jobs_by_gender_and_age.csv')

# %%
df3 = pd.read_csv('Number_of_filled_jobs_by_gender_and_region.csv')

# %%
df4 = pd.read_csv('Number_of_filled_jobs_by_industry.csv')

# %%
df1 = pd.read_csv('Number_of_filled_jobs_by_age_region.csv', header= [0,1])

# %%
sns.pairplot(df2)

# %%
df1
# Out:
#    Unnamed: 0_level_0     15-19                                          \
#            Year/Month Northland Auckland Waikato Bay of Plenty Gisborne
# 0             2019M05      4235    33186   11638          8225     1417
# 1             2019M06      4064    32410   11379          7917     1365
# 2             2019M07      4088    32517   11457          7867     1406
# 3             2019M08      4050    32185   11281          7692     1333
# 4             2019M09      4100    32404   11520          7758     1315
# 5             2019M10      4284    33495   12082          8050     1485
# 6             2019M11      4709    36229   12904          8754     1581
# 7             2019M12      5299    40418   14324          9633     1911
# 8             2020M01      5020    35671   13266          9040     1797
# 9             2020M02      4698    35833   12866          8584     1681
# 10            2020M03      4355    33394   11822          8078     1603
# ...

# %%
df2 = pd.read_csv('Number_of_filled_jobs_by_gender_and_age.csv', skiprows=2)

# %%
df2
# Out:
#    Unnamed: 0  15-19   20-24   25-29   30-34   35-39   40-44   45-49   50-54  \
# 0     2019M05  54850  119698  145180  129457  114195  103311  108064   98578
# 1     2019M06  53492  117861  143946  129264  114342  103686  108064   98568
# 2     2019M07  54256  117785  143978  130147  114960  104280  108339   98955
# 3     2019M08  52586  117292  143821  130463  115285  104168  108338   98924
# 4     2019M09  53281  117531  144126  131146  115771  104460  108642   99175
# 5     2019M10  55592  118195  144703  131812  116234  104615  108708   99390
# 6     2019M11  59602  122356  147217  134013  117989  105929  109637  100342
# 7     2019M12  66469  124540  146923  134349  118068  106021  109335  100496
# 8     2020M01  61167  119673  143815  133343  117409  105182  108722   99816
# 9     2020M02  59727  122237  145544  135004  118584  106041  109118  100359
# 10    2020M03  55740  120456  146942  136418  119916  106788  109632  101019
# ...

# %%
df3 = pd.read_csv('Number_of_filled_jobs_by_gender_and_region.csv',  header= [0,1])

# %%
df3
# Out:
#    Unnamed: 0_level_0      Male Unnamed: 2_level_0 Unnamed: 3_level_0  \
#            Year/Month Northland           Auckland            Waikato
# 0             2019M05     32579             368717             101098
# 1             2019M06     32273             369307             102111
# 2             2019M07     32116             373454             102280
# 3             2019M08     32038             373624             102349
# 4             2019M09     32370             375584             103135
# 5             2019M10     32617             377988             104285
# 6             2019M11     33471             383297             105856
# 7             2019M12     33725             384872             106818
# 8             2020M01     32916             376234             105084
# 9             2020M02     33152             380954             105915
# 10            2020M03     33244             381575             105656
# ...

# %%
df4 = pd.read_csv('Number_of_filled_jobs_by_industry.csv', header= [0])

# %%
df4
# Out:
#     Year  Month  Agriculture, Forestry and Fishing  Mining  Manufacturing  \
# 0   2019      5                              96007    5624         232878
# 1   2019      6                              92219    5667         227383
# 2   2019      7                              92710    5790         225474
# 3   2019      8                              93407    5761         227200
# 4   2019      9                              94106    5776         226052
# 5   2019     10                              97250    5625         230193
# 6   2019     11                             105864    5620         235073
# 7   2019     12                             112040    5614         238109
# 8   2020      1                             108667    5695         234708
# 9   2020      2                             106052    5410         237359
# 10  2020      3                             103340    5820         235866
# 11  2020      4                              98787    5320         232510
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Columns: 188 entries, ('Unnamed: 0_level_0', 'Year/Month') to ('65', 'Total NZ')
# dtypes: int64(187), object(1)
# memory usage: 53.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  36 non-null     object
#  1   15-19       36 non-null     int64
#  2   20-24       36 non-null     int64
#  3   25-29       36 non-null     int64
#  4   30-34       36 non-null     int64
#  5   35-39       36 non-null     int64
#  6   40-44       36 non-null     int64
#  7   45-49       36 non-null     int64
#  8   50-54       36 non-null     int64
#  9   55-59       36 non-null     int64
#  10  60-64       36 non-null     int64
#  11  65          36 non-null     int64
#  12  15-19.1     36 non-null     int64
#  13  20-24.1     36 non-null     int64
#  14  25-29.1     36 non-null     int64
#  15  30-34.1     36 non-null     int64
#  16  35-39.1     36 non-null     int64
#  17  40-44.1     36 non-null     int64
#  18  45-49.1     36 non-null     int64
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   (Unnamed: 0_level_0, Year/Month)           36 non-null     object
#  1   (Male, Northland)                          36 non-null     int64
#  2   (Unnamed: 2_level_0, Auckland)             36 non-null     int64
#  3   (Unnamed: 3_level_0, Waikato)              36 non-null     int64
#  4   (Unnamed: 4_level_0, Bay of Plenty)        36 non-null     int64
#  5   (Unnamed: 5_level_0, Gisborne)             36 non-null     int64
#  6   (Unnamed: 6_level_0, Hawke's Bay)          36 non-null     int64
#  7   (Unnamed: 7_level_0, Taranaki)             36 non-null     int64
#  8   (Unnamed: 8_level_0, Manawatu-Whanganui)   36 non-null     int64
#  9   (Unnamed: 9_level_0, Wellington)           36 non-null     int64
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 21 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Year                                             36 non-null     int64
#  1   Month                                            36 non-null     int64
#  2   Agriculture, Forestry and Fishing                36 non-null     int64
#  3   Mining                                           36 non-null     int64
#  4   Manufacturing                                    36 non-null     int64
#  5   Electricity, Gas, Water and Waste Services       36 non-null     int64
#  6   Construction                                     36 non-null     int64
#  7   Wholesale Trade                                  36 non-null     int64
#  8   Retail Trade                                     36 non-null     int64
# ...

# %%
df1.min()
# Out:
# Unnamed: 0_level_0  Year/Month       2019M05
# 15-19               Northland           3875
#                     Auckland           28266
#                     Waikato            10932
#                     Bay of Plenty       7210
#                                       ...
# 65                  West Coast           883
#                     Canterbury         13349
#                     Otago               5065
#                     Southland           2559
#                     Total NZ          102086
# Length: 188, dtype: object

# %%
df1.max()
# Out:
# Unnamed: 0_level_0  Year/Month       2022M04
# 15-19               Northland           5994
#                     Auckland           44805
#                     Waikato            16107
#                     Bay of Plenty      10933
#                                       ...
# 65                  West Coast          1022
#                     Canterbury         15158
#                     Otago               5756
#                     Southland           2906
#                     Total NZ          115546
# Length: 188, dtype: object

# %%
df1.mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9788\2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# 15-19  Northland          4613.222222
#        Auckland          34252.583333
#        Waikato           12620.416667
#        Bay of Plenty      8540.027778
#        Gisborne           1620.916667
#                             ...
# 65     West Coast          947.777778
#        Canterbury        14279.305556
#        Otago              5401.666667
#        Southland          2713.833333
#        Total NZ         108353.527778
# Length: 187, dtype: float64

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
columns = df1.columns
index = df1.index
data = df1.values

# %%
columns
# Out:
# MultiIndex([('Unnamed: 0_level_0',         'Year/Month'),
#             (             '15-19',          'Northland'),
#             (             '15-19',           'Auckland'),
#             (             '15-19',            'Waikato'),
#             (             '15-19',      'Bay of Plenty'),
#             (             '15-19',           'Gisborne'),
#             (             '15-19',        'Hawke's Bay'),
#             (             '15-19',           'Taranaki'),
#             (             '15-19', 'Manawatu-Whanganui'),
#             (             '15-19',         'Wellington'),
#             ...
#             (                '65', 'Manawatu-Whanganui'),
#             (                '65',         'Wellington'),
#             (                '65',             'Tasman'),
#             (                '65',             'Nelson'),
#             (                '65',        'Marlborough'),
#             (                '65',         'West Coast'),
# ...

# %%
index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %%
df4.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3.hist(bins=6);
plt.xticks(rotation=40)
# Out:
# (array([0., 1.]), [Text(0, 0, ''), Text(0, 0, '')])

# %%
df4.hist(column='Agriculture, Forestry and Fishing');

# %%
df4.plot(kind='bar',x='Year',y='Agriculture, Forestry and Fishing')
df4.plot(kind='bar',x='Year',y='Professional, Scientific and Technical Services')
df4.plot(kind='bar',x='Year',y='Accommodation and Food Services')
df4.plot(kind='bar',x='Year',y='Health Care and Social Assistance')
plt.show()

# %%
df4.head(15)
# Out:
#     Year  Month  Agriculture, Forestry and Fishing  Mining  Manufacturing  \
# 0   2019      5                              96007    5624         232878
# 1   2019      6                              92219    5667         227383
# 2   2019      7                              92710    5790         225474
# 3   2019      8                              93407    5761         227200
# 4   2019      9                              94106    5776         226052
# 5   2019     10                              97250    5625         230193
# 6   2019     11                             105864    5620         235073
# 7   2019     12                             112040    5614         238109
# 8   2020      1                             108667    5695         234708
# 9   2020      2                             106052    5410         237359
# 10  2020      3                             103340    5820         235866
# 11  2020      4                              98787    5320         232510
# ...

# %%
x1= df4['Accommodation and Food Services']
x2= df4['Agriculture, Forestry and Fishing']

# %%
plt.figure(figsize = (20 , 5))
plt.hist([x1,x2], label =['Accommodation and Food Services', 'Agriculture, Forestry and Fishing'], bins = 35 , alpha = 0.5)
plt.legend(borderpad=0.5, fontsize=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df2.head(10)
# Out:
#   Unnamed: 0  15-19   20-24   25-29   30-34   35-39   40-44   45-49   50-54  \
# 0    2019M05  54850  119698  145180  129457  114195  103311  108064   98578
# 1    2019M06  53492  117861  143946  129264  114342  103686  108064   98568
# 2    2019M07  54256  117785  143978  130147  114960  104280  108339   98955
# 3    2019M08  52586  117292  143821  130463  115285  104168  108338   98924
# 4    2019M09  53281  117531  144126  131146  115771  104460  108642   99175
# 5    2019M10  55592  118195  144703  131812  116234  104615  108708   99390
# 6    2019M11  59602  122356  147217  134013  117989  105929  109637  100342
# 7    2019M12  66469  124540  146923  134349  118068  106021  109335  100496
# 8    2020M01  61167  119673  143815  133343  117409  105182  108722   99816
# 9    2020M02  59727  122237  145544  135004  118584  106041  109118  100359
#
#    55-59  ...  20-24.1  25-29.1  30-34.1  35-39.1  40-44.1  45-49.1  50-54.1  \
# ...

# %%
import matplotlib.pyplot as plt
>>> df2.plot(x="Unnamed: 0", y="15-19.1")
plt.xticks(rotation=40)
>>> plt.show()

# %%
import matplotlib.pyplot as plt
>>> df2.plot(x="Unnamed: 0", y="15-19")
plt.xticks(rotation=40)
>>> plt.show()

# %%
x1= df2['15-19']
x2= df2['15-19.1']

# %%
plt.figure(figsize = (8 , 10))
plt.hist([x1,x2], label =['15-19', '15-19.1'], bins = 35 , alpha = 0.5)
plt.legend(borderpad=0.5, fontsize=18)
plt.xticks(rotation=40)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
to_plot = df3[('Male','Northland')]
plt.xticks(rotation=40)
plt.hist(to_plot)
# Out:
# (array([4., 8., 1., 5., 4., 5., 2., 4., 0., 3.]),
#  array([32038. , 32407.3, 32776.6, 33145.9, 33515.2, 33884.5, 34253.8,
#         34623.1, 34992.4, 35361.7, 35731. ]),
#  <BarContainer object of 10 artists>)

# %%
to_plot = df3[('Female','Northland')]
plt.hist(to_plot)
# Out:
# (array([5., 6., 2., 4., 3., 4., 4., 5., 1., 2.]),
#  array([34249. , 34698.2, 35147.4, 35596.6, 36045.8, 36495. , 36944.2,
#         37393.4, 37842.6, 38291.8, 38741. ]),
#  <BarContainer object of 10 artists>)

# %%
x1 =df3[('Male','Northland')]
x2 =df3[('Female','Northland')]

# %%
plt.figure(figsize = (30 , 5))
plt.hist([x1,x2], label =[('Male','Northland'), ('Female','Northland')], bins = 40 , alpha = 0.5)
plt.legend(borderpad=0.5, fontsize=25)
plt.xticks(rotation=60)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
to_plot_male = df3[('Male','Northland')]
to_plot_female = df3[('Female','Northland')]
plt.hist(to_plot_male, alpha=0.3, color='blue')
plt.hist(to_plot_female, alpha=0.3, color='red')
plt.show()

# %%
fig, ax = plt.subplots()
df4.plot(x = 'Year', y = 'Rental, Hiring and Real Estate Services', ax = ax) 
df4.plot(x = 'Year', y = 'Education and Training', ax = ax, secondary_y = True)
# Out:
# <AxesSubplot:>
